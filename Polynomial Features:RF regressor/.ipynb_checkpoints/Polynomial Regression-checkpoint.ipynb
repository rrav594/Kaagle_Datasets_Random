# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
data = pd.read_csv('Position_Salaries.csv')
print(data.shape)
data.head()
# Out:
# (10, 3)
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
sns.pairplot(data);

# %%
plt.hist(data['Salary'],bins = 20);

# %%
data_y = data.pop('Salary')
data_x = pd.DataFrame(data['Level'])

# %%
scaler = StandardScaler()
data_y.shape
# Out:
# (10,)

# %%
data_y = pd.DataFrame(scaler.fit_transform(pd.DataFrame(data_y)))

# %%
data_y.rename(columns = {0:'Salary'},inplace = True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size = 0.3, random_state = 14)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_lr = lr.predict(X_test)
y_pred_lr
# Out:
# array([[-0.52638806],
#        [ 0.65314371],
#        [-1.11615394]])

# %%
plt.scatter(data_x, data_y, color = 'red')
plt.scatter(X_test, y_pred_lr, color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
poly = PolynomialFeatures(degree = 5)
x_poly = pd.DataFrame(poly.fit_transform(X_train))

# %%
lr_poly = LinearRegression()
lr_poly.fit(x_poly,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_poly = lr_poly.predict(poly.fit_transform(X_test))

# %%
plt.scatter(data_x, data_y, color = 'red')
plt.scatter(X_test, y_pred_poly, color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred_lr)
# Out:
# 1.3731381986823656

# %%
mean_squared_error(y_test,y_pred_poly)
# Out:
# 0.03937918901866147
